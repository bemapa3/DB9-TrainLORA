# %% [markdown]
# # 2. Prepare Dataset
#
# Xử lý dataset (resize, convert) và tự động tạo caption bằng Gemini.

# %%
import os
from pathlib import Path
if Path.cwd().name == "notebooks":
    os.chdir("..")
print(f"Current working directory: {Path.cwd()}")

# %%
import os
from dotenv import load_dotenv

load_dotenv('.env')

# %% [markdown]
# ## 2.1. Clean Dataset

# %%
# !python scripts/data_clean.py --input datasets/raw --output datasets/processed/img --min-res 512 --max-res 4096 --format jpg

# %% [markdown]
# ## 2.2. Auto Caption (Gemini Flash)

# %%
# !python scripts/caption_gemini.py --input datasets/processed/img --output datasets/processed/captions --prompt "Mô tả chi tiết hình ảnh này"
