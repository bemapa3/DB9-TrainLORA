# %% [markdown]
# # 4. Train
#
# Bắt đầu quá trình training.

# %%
import os
from pathlib import Path
if Path.cwd().name == "notebooks":
    os.chdir("..")
print(f"Current working directory: {Path.cwd()}")

# %%
# !cd ai-toolkit && python run.py ../configs/sdvn_flux_lora.yaml
